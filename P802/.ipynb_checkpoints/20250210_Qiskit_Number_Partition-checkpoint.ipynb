# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit.circuit.library import RZGate, RZZGate
from qiskit.providers.basic_provider import BasicSimulator
from qiskit.visualization import plot_histogram
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
gamma = 0.5   # Cost unitary parameter
beta  = 0.3   # Mixing unitary parameter
n_qubits = 3  # Four spins / qubits

trotter_steps = 100
T = 10.0  

# Create a QuantumCircuit with 4 qubits and 4 classical bits
qc = QuantumCircuit(n_qubits, n_qubits)

# === STEP 1: Prepare a uniform superposition ===
for i in range(n_qubits):
    qc.h(i)

# Time-dependent interpolation
def s(t):
    return t / T

# Step 2: Trotterized evolution
for step in range(trotter_steps):
    # === STEP 2: Apply the Cost Unitary U_C(gamma) ===
    # H_C = 4 Z0 Z1 + 4 Z0 Z2 + 6 Z0 Z3 + 8 Z1 Z2 + 12 Z1 Z3 + 12 Z2 Z3
    # Implement each ZZ term using Rzz.

    t = (step + 1) * (T / trotter_steps)
    s_t = s(t)
    
    #qc.rzz(-2 * s_t * gamma * 4 * (T / trotter_steps), 0, 1)
    #qc.rzz(-2 * s_t * gamma * 4 * (T / trotter_steps), 0, 2)
    #qc.rzz(-2 * s_t * gamma * 6 * (T / trotter_steps), 0, 3)
    #qc.rzz(-2 * s_t * gamma * 8 * (T / trotter_steps), 1, 2)
    #qc.rzz(-2 * s_t * gamma * 12 * (T / trotter_steps), 1, 3)
    #qc.rzz(-2 * s_t * gamma * 12 * (T / trotter_steps), 2, 3)

    qc.rzz(-2 * s_t * gamma * 4 * (T / trotter_steps), 0, 1)
    qc.rzz(-2 * s_t * gamma * 6 * (T / trotter_steps), 0, 2)
    qc.rzz(-2 * s_t * gamma * 12 * (T / trotter_steps), 1, 2)
    
    
# === STEP 3: Apply the Mixing Unitary U_M(beta) ===
for i in range(n_qubits):
    qc.rx(2 * beta, i)

# === STEP 4: Measurement ===
qc.measure(range(n_qubits), range(n_qubits))

# Draw the circuit
#qc.draw(output='mpl', style='iqp')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/.venv/lib/python3.13/site-packages/qiskit/circuit/quantumcircuit.py:6753, in _bit_argument_conversion(specifier, bit_sequence, bit_set, type_)
#    6752 try:
# -> 6753     return [bit_sequence[specifier]]
#    6754 except IndexError as ex:
#
# IndexError: list index out of range
#
# The above exception was the direct cause of the following exception:
#
# CircuitError                              Traceback (most recent call last)
# Cell In[1], line 38
#      36 qc.rzz(-2 * s_t * gamma * 4 * (T / trotter_steps), 0, 1)
#      37 #qc.rzz(-2 * s_t * gamma * 4 * (T / trotter_steps), 0, 2)
# ---> 38 qc.rzz(-2 * s_t * gamma * 6 * (T / trotter_steps), 0, 3)
#      39 #qc.rzz(-2 * s_t * gamma * 8 * (T / trotter_steps), 1, 2)
#      40 #qc.rzz(-2 * s_t * gamma * 12 * (T / trotter_steps), 1, 3)
#      41 qc.rzz(-2 * s_t * gamma * 12 * (T / trotter_steps), 2, 3)
#
# File ~/.venv/lib/python3.13/site-packages/qiskit/circuit/quantumcircuit.py:4982, in QuantumCircuit.rzz(self, theta, qubit1, qubit2)
#    4967 def rzz(
#    4968     self, theta: ParameterValueType, qubit1: QubitSpecifier, qubit2: QubitSpecifier
#    4969 ) -> InstructionSet:
#    4970     """Apply :class:`~qiskit.circuit.library.RZZGate`.
#    4971
#    4972     For the full matrix form of this gate, see the underlying gate documentation.
#    (...)
#    4980         A handle to the instructions created.
#    4981     """
# -> 4982     return self._append_standard_gate(StandardGate.RZZGate, [qubit1, qubit2], [theta])
#
# File ~/.venv/lib/python3.13/site-packages/qiskit/circuit/quantumcircuit.py:2444, in QuantumCircuit._append_standard_gate(self, op, qargs, params, label)
#    2441 if params is None:
#    2442     params = []
# -> 2444 expanded_qargs = [self._qbit_argument_conversion(qarg) for qarg in qargs or []]
#    2445 for param in params:
#    2446     Gate.validate_parameter(op, param)
#
# File ~/.venv/lib/python3.13/site-packages/qiskit/circuit/quantumcircuit.py:2393, in QuantumCircuit._qbit_argument_conversion(self, qubit_representation)
#    2382 def _qbit_argument_conversion(self, qubit_representation: QubitSpecifier) -> list[Qubit]:
#    2383     """
#    2384     Converts several qubit representations (such as indexes, range, etc.)
#    2385     into a list of qubits.
#    (...)
#    2391         The resolved instances of the qubits.
#    2392     """
# -> 2393     return _bit_argument_conversion(
#    2394         qubit_representation, self.qubits, self._qubit_indices, Qubit
#    2395     )
#
# File ~/.venv/lib/python3.13/site-packages/qiskit/circuit/quantumcircuit.py:6755, in _bit_argument_conversion(specifier, bit_sequence, bit_set, type_)
#    6753         return [bit_sequence[specifier]]
#    6754     except IndexError as ex:
# -> 6755         raise CircuitError(
#    6756             f"Index {specifier} out of range for size {len(bit_sequence)}."
#    6757         ) from ex
#    6758 # Slices can't raise IndexError - they just return an empty list.
#    6759 if isinstance(specifier, slice):
#
# CircuitError: 'Index 3 out of range for size 3.'

# %%
simulator = BasicSimulator()

# Simulate the circuit
compiled_circuit = transpile(qc, simulator)
job = simulator.run(compiled_circuit, shots=1024)
result = job.result()
counts = result.get_counts()

# Print the counts
print(result.get_counts())

# Plot the histogram
plot_histogram(result.get_counts())
# Out:
# {'1001': 167, '1011': 68, '0001': 62, '0110': 157, '0011': 51, '1000': 50, '1110': 70, '1101': 71, '0010': 72, '0111': 49, '0100': 69, '1100': 41, '1010': 47, '0101': 43, '1111': 5, '0000': 2}
