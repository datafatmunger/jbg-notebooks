# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit.circuit.library import RZGate, RZZGate
from qiskit.providers.basic_provider import BasicSimulator
from qiskit.visualization import plot_histogram
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
gamma = 0.5   # Cost unitary parameter
beta  = 0.5   # Mixing unitary parameter
n_qubits = 3  # Four spins / qubits

trotter_steps = 10
T = 1.0

# Create a QuantumCircuit with 4 qubits and 4 classical bits
qr = QuantumRegister(n_qubits)
cr = ClassicalRegister(n_qubits, name='cr')
qc = QuantumCircuit(qr, cr)

# === STEP 1: Prepare a uniform superposition ===
for i in range(n_qubits):
    qc.h(i)

# Step 2: Trotterized evolution
for step in range(trotter_steps):
    # === STEP 2: Apply the Cost Unitary U_C(gamma) ===
    # H_C = 4 Z0 Z1 + 4 Z0 Z2 + 6 Z0 Z3 + 8 Z1 Z2 + 12 Z1 Z3 + 12 Z2 Z3
    # Implement each ZZ term using Rzz.

    t = (step + 1) * (T / trotter_steps)
    #s_t = t / T
    s_t = 1
    
    #qc.rzz(-2 * s_t * gamma * 4 * (T / trotter_steps), 0, 1)
    #qc.rzz(-2 * s_t * gamma * 4 * (T / trotter_steps), 0, 2)
    #qc.rzz(-2 * s_t * gamma * 6 * (T / trotter_steps), 0, 3)
    #qc.rzz(-2 * s_t * gamma * 8 * (T / trotter_steps), 1, 2)
    #qc.rzz(-2 * s_t * gamma * 12 * (T / trotter_steps), 1, 3)
    #qc.rzz(-2 * s_t * gamma * 12 * (T / trotter_steps), 2, 3)

    qc.rzz(-2 * s_t * gamma * 6 * (T / trotter_steps), 0, 1)
    qc.rzz(-2 * s_t * gamma * 4 * (T / trotter_steps), 0, 2)
    qc.rzz(-2 * s_t * gamma * 12 * (T / trotter_steps), 1, 2)
    
    #qc.rzz(abs(-2 * s_t * gamma * 6 * (T / trotter_steps)), 0, 1)
    #qc.rzz(abs(-2 * s_t * gamma * 4 * (T / trotter_steps)), 0, 2)
    #qc.rzz(abs(-2 * s_t * gamma * 12 * (T / trotter_steps)), 1, 2)    
    
# === STEP 3: Apply the Mixing Unitary U_M(beta) ===
for i in range(n_qubits):
    qc.rx(2 * beta, i)

# === STEP 4: Measurement ===
qc.measure(range(n_qubits), range(n_qubits))

# Draw the circuit
#qc.draw(output='mpl', style='iqp')

# %%
simulator = BasicSimulator()

# Simulate the circuit
compiled_circuit = transpile(qc, simulator)
job = simulator.run(compiled_circuit, shots=1024)
result = job.result()
counts = result.get_counts()

# Print the counts
print(result.get_counts())

# Plot the histogram
plot_histogram(result.get_counts())
# Out:
# {'110': 13, '010': 346, '100': 146, '101': 321, '011': 137, '000': 24, '001': 12, '111': 25}

# %%
# Use the following code instead if you want to run on a simulator:
from qiskit_ibm_runtime.fake_provider import FakeKyiv

backend = FakeKyiv()

# Define Sampler
sampler = Sampler(mode=backend)

compiled_circuit = transpile(qc, backend)

# Run calculation
job = sampler.run([compiled_circuit], shots=1024)
 
result = job.result()

counts = result[0].data.cr.get_counts()

print(counts)

# Plot the histogram
plot_histogram(counts)
# Out:
# {'110': 132, '111': 122, '010': 130, '011': 131, '001': 153, '100': 109, '000': 114, '101': 133}

# %%
backend = BasicSimulator()

# Define Sampler
sampler = Sampler(mode=backend)

compiled_circuit = transpile(qc, backend)

# Run calculation
job = sampler.run([compiled_circuit], shots=1024)
 
result = job.result()

counts = result[0].data.cr.get_counts()

print(counts)

# Plot the histogram
plot_histogram(counts)
# Out:
# {'100': 141, '011': 145, '010': 322, '101': 354, '111': 18, '110': 7, '001': 13, '000': 24}

# %%
from qiskit_ibm_runtime import SamplerV2 as Sampler, QiskitRuntimeService
 
api_token = '...'
# If you did not previously save your credentials, use the following line instead:
service = QiskitRuntimeService(channel="ibm_quantum", token=api_token)
 
# Get a backend
backend = service.least_busy(operational=True, simulator=False)
 
# Define Sampler
sampler = Sampler(mode=backend)

compiled_circuit = transpile(qc, backend)

# Run calculation
#job = sampler.run([compiled_circuit], shots=1024)
 
result = job.result()

counts = result[0].data.cr.get_counts()

print(counts)

# Plot the histogram
plot_histogram(counts)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.venv/lib/python3.13/site-packages/qiskit_ibm_runtime/api/session.py:328, in RetrySession.request(self, method, url, bare, **kwargs)
#     327     response = super().request(method, final_url, headers=headers, **kwargs)
# --> 328     response.raise_for_status()
#     329 except RequestException as ex:
#     330     # Wrap the requests exceptions into a IBM Q custom one, for
#     331     # compatibility.
#
# File ~/.venv/lib/python3.13/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://auth.quantum.ibm.com/api/users/loginWithToken
#
# The above exception was the direct cause of the following exception:
#
# IBMNotAuthorizedError                     Traceback (most recent call last)
# Cell In[72], line 5
#       3 api_token = '...'
#       4 # If you did not previously save your credentials, use the following line instead:
# ----> 5 service = QiskitRuntimeService(channel="ibm_quantum", token=api_token)
#       7 # Get a backend
#       8 backend = service.least_busy(operational=True, simulator=False)
#
# File ~/.venv/lib/python3.13/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:158, in QiskitRuntimeService.__init__(self, channel, token, url, filename, name, instance, proxies, verify, private_endpoint, url_resolver)
#     156     self._backend_allowed_list = self._discover_cloud_backends()
#     157 else:
# --> 158     auth_client = self._authenticate_ibm_quantum_account(self._client_params)
#     159     # Update client parameters to use authenticated values.
#     160     self._client_params.url = auth_client.current_service_urls()["services"]["runtime"]
#
# File ~/.venv/lib/python3.13/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:280, in QiskitRuntimeService._authenticate_ibm_quantum_account(self, client_params)
#     273 if not version_info["new_api"] or "api-auth" not in version_info:
#     274     raise IBMInputValueError(
#     275         "The URL specified ({}) is not an IBM Quantum authentication URL. "
#     276         "Valid authentication URL: {}.".format(
#     277             client_params.url, QISKIT_IBM_RUNTIME_API_URL
#     278         )
#     279     )
# --> 280 auth_client = AuthClient(client_params)
#     281 service_urls = auth_client.current_service_urls()
#     282 if not service_urls.get("services", {}).get(SERVICE_NAME):
#
# File ~/.venv/lib/python3.13/site-packages/qiskit_ibm_runtime/api/clients/auth.py:39, in AuthClient.__init__(self, client_params)
#      36 self._service_urls = {}  # type: ignore[var-annotated]
#      38 self.auth_api = Api(RetrySession(self.auth_url, **client_params.connection_parameters()))
# ---> 39 self.base_api = self._init_service_clients(**client_params.connection_parameters())
#
# File ~/.venv/lib/python3.13/site-packages/qiskit_ibm_runtime/api/clients/auth.py:51, in AuthClient._init_service_clients(self, **request_kwargs)
#      42 """Initialize the clients used for communicating with the API.
#      43
#      44 Args:
#    (...)
#      48     Client for the API server.
#      49 """
#      50 # Request an access token.
# ---> 51 self.access_token = self._request_access_token()
#      52 self.auth_api.session.auth = QuantumAuth(access_token=self.access_token)
#      53 self._service_urls = self.user_urls()
#
# File ~/.venv/lib/python3.13/site-packages/qiskit_ibm_runtime/api/clients/auth.py:77, in AuthClient._request_access_token(self)
#      67 """Request a new access token from the API authentication service.
#      68
#      69 Returns:
#    (...)
#      74     RequestsApiError: If the request failed.
#      75 """
#      76 try:
# ---> 77     response = self.auth_api.login(self.api_token)
#      78     return response["id"]
#      79 except RequestsApiError as ex:
#      80     # Get the original exception that raised.
#
# File ~/.venv/lib/python3.13/site-packages/qiskit_ibm_runtime/api/rest/root.py:93, in Api.login(self, api_token)
#      84 """Login with token.
#      85
#      86 Args:
#    (...)
#      90     JSON response.
#      91 """
#      92 url = self.get_url("login")
# ---> 93 return self.session.post(
#      94     url, json={"apiToken": api_token}, headers=self._HEADER_JSON_CONTENT
#      95 ).json()
#
# File ~/.venv/lib/python3.13/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/.venv/lib/python3.13/site-packages/qiskit_ibm_runtime/api/session.py:349, in RetrySession.request(self, method, url, bare, **kwargs)
#     347         message += f". {ex.response.text}"
#     348 if status_code == 401:
# --> 349     raise IBMNotAuthorizedError(message) from ex
#     350 if status_code == 503:  # Planned maintenance outage
#     351     raise RequestsApiError(
#     352         "Unexpected response received from server. Please check if the service "
#     353         "is in maintenance mode "
#     354         f"https://docs.quantum.ibm.com/announcements/service-alerts {message}"
#     355     )
#
# IBMNotAuthorizedError: '401 Client Error: Unauthorized for url: https://auth.quantum.ibm.com/api/users/loginWithToken. Login failed., Error code: 3446.'
