# %%
import pennylane as qml
import numpy as np

dev = qml.device("default.qubit", wires=2)

@qml.qnode(dev)
def circuit1():
    qml.Hadamard(wires=0)
    qml.Hadamard(wires=1)
    qml.CNOT(wires=[0, 1])
    qml.Hadamard(wires=0)
    qml.Hadamard(wires=1)
    return qml.state()

@qml.qnode(dev)
def circuit2():
    qml.CNOT(wires=[1, 0])
    return qml.state()


qml.draw_mpl(circuit1)()
qml.draw_mpl(circuit2)()

# Extract the unitary matrix representations of the circuits
unitary1 = qml.matrix(circuit1)()
unitary2 = qml.matrix(circuit2)()

def test_circuit_equivalence():
    assert np.allclose(unitary1, unitary2), "Circuits are not equivalent!"
    print("Test passed: Circuits are equivalent.")

test_circuit_equivalence()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 35
#      32     assert np.allclose(unitary1, unitary2), "Circuits are not equivalent!"
#      33     print("Test passed: Circuits are equivalent.")
# ---> 35 test_circuit_equivalence()
#
# Cell In[8], line 32, in test_circuit_equivalence()
#      31 def test_circuit_equivalence():
# ---> 32     assert np.allclose(unitary1, unitary2), "Circuits are not equivalent!"
#      33     print("Test passed: Circuits are equivalent.")
#
# AssertionError: Circuits are not equivalent!
