# %% [markdown]
# #### 1. Importing all the libraries

# %%
import os
import sys
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.collections import LineCollection

import torch
import torch.nn as nn
import torch.optim as optim
import pennylane as qml

from sklearn import tree, metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier

import time

# %% [markdown]
# #### 2. Define the Functions

# %%
# Function that create the episode data - sample randomaly
def get_data(episode_size,policy,mode):
    global dataset
    if mode=='train':
        if policy==0:
             dataset=data.sample(n=episode_size)
        else:
            dataset=data
    else:
        dataset = pd.read_csv(location + '/' + file +'_test_int.csv', index_col=0)
    return dataset

# %%
# Function that separate the episode data into features and label
def data_separate (dataset):
    global X
    global y    
    X = dataset.iloc[:,0:dataset.shape[1]-1]  # all rows, all the features and no labels
    y = dataset.iloc[:, -1]  # all rows, label only
    return X,y

# %%
# Function that split the episode data into train and test
def data_split(X,y):
    global X_train_main
    global X_test_main   
    global y_train
    global y_test  
    from sklearn.model_selection import train_test_split
    X_train_main, X_test_main, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=4)
    return X_train_main, X_test_main, y_train, y_test

# %%
# Function that chooses exploration or explotation method
def exploration_explotation(epsilon):
    global exploration 
    if np.random.rand() < epsilon:  
        exploration=1
    else:
        exploration=0    
    return exploration

# %%
# Function that returns all available actions in the state given as an argument: 
def available_actions(number_of_columns,columns,initial_state,current_state,trashold, exploration):
    global exclude
    global all_columns
#    exclude=[]
    all_columns=np.arange(number_of_columns+1)
    # remove columns that have been already selected
    exclude=columns.copy()
    # remove the initial_state and the current_state
    exclude.extend([initial_state, current_state])
    available_act = list(set(all_columns)-set(exclude))
    # remove actions that have negetiv Q value
    if exploration==0:
        index = np.where(Q[current_state,available_act] > trashold)[1]
        available_act= [available_act[i] for i in index.tolist()]
    return available_act

# %%
def sample_next_action(current_state, Q, available_act, exploration):
    global available_act_q_value
    available_act_q_value = [float(q) for q in np.array(Q[current_state, available_act]).reshape(-1)]
    
    if exploration == 1: 
        # Random selection
        next_action = int(np.random.choice(available_act, 1).item())
    else: 
        # Greedy selection according to max value
        maxQ = max(available_act_q_value)
        count = available_act_q_value.count(maxQ)
        
        if count > 1:
            max_columns = [i for i in range(len(available_act_q_value)) if available_act_q_value[i] == maxQ]
            i = int(np.random.choice(max_columns, 1).item())
        else:
            i = available_act_q_value.index(maxQ)
        
        next_action = available_act[i]  
    
    return next_action

# %%
# function that update a list with all selected columns in the episode
def update_columns(action, columns):
    update_columns=columns
    update_columns.append(action)
    return update_columns

# %%
# function that update the X_train and X_test according to the current episode columns list 
def update_X_train_X_test(columns,X_train_main, X_test_main):
    X_train=X_train_main.iloc[:,columns]
    X_test=X_test_main.iloc[:,columns]
    X_train=pd.DataFrame(X_train)
    X_test=pd.DataFrame(X_test)
    return X_train, X_test

# %%
# Function that run the learner and get the error to the current episode columns list
def Learner(X_train, X_test,y_train, y_test):
    global learner
    global y_pred
    if learner_model == 'DT':
        learner = tree.DecisionTreeClassifier()
        learner = learner.fit(X_train, y_train)
        y_pred = learner.predict(X_test)
    elif learner_model == 'KNN':
        learner = KNeighborsClassifier(metric='hamming',n_neighbors=5)
        learner = learner.fit(X_train, y_train)
        y_pred = learner.predict(X_test)        
    elif learner_model == 'SVM':
        learner = SVC()
        learner = learner.fit(X_train, y_train)
        y_pred = learner.predict(X_test)        
    elif learner_model == 'NB':
        learner = MultinomialNB()
        learner = learner.fit(X_train, y_train)
        y_pred = learner.predict(X_test)
    elif learner_model == 'AB':
        learner = AdaBoostClassifier()
        learner = learner.fit(X_train, y_train)
        y_pred = learner.predict(X_test)  
    elif learner_model == 'GB':
        learner = GradientBoostingClassifier()
        learner = learner.fit(X_train, y_train)
        y_pred = learner.predict(X_test)  
    elif learner_model == 'VQC':
        learner = QuantumLearner()
        learner = learner.fit(X_train, y_train)
        y_pred = learner.predict(X_test)  
    elif learner_model == 'ANN':
        learner = ClassicalLearner()
        learner = learner.fit(X_train, y_train)
        y_pred = learner.predict(X_test)  
    accuracy=metrics.accuracy_score(y_test, y_pred)
    error=1-accuracy
    return error

# %%
def q_update(current_state, action, learning_rate, reward):
    # next_state = current action
    max_index = np.where(Q[action,] == np.max(Q[action,]))[0]  # Use [0] instead of [1] for 1D arrays
    
    if max_index.shape[0] > 1:
        # Resolve tie by selecting one randomly
        max_index = int(np.random.choice(max_index, size=1).item())
    else:
        max_index = int(max_index[0])  # Convert the first element to a scalar

    max_value = Q[action, max_index]

    # Update the Q matrix
    if Q[current_state, action] == 1:
        Q[current_state, action] = learning_rate * reward
    else:
        Q[current_state, action] = Q[current_state, action] + learning_rate * (
            reward + (discount_factor * max_value) - Q[current_state, action]
        )

# %% [markdown]
# ### Experiment mangment

# %% [markdown]
# #### 3. Define the parameters

# %%
## for run time ##
N_features=2
N_data=1
## for run time ##

#Experiment: 
experiment='test'
number_of_experiment=1

# Dataset parameters #
location = 'Datasets/adult'
outputlocation='Datasets'
file='adult' #adult #diabetic_data #no_show
#np.random.seed(3)

# Q learning parameter # 
learning_rate=0.005
discount_factor = 0.01 #0
epsilon = 0.1

# Learner and episode parameters #
learner_model = 'VQC' #DT #KNN #SVM
episode_size=10
internal_trashold=0
external_trashold=0
filename= file +'_int.csv'

#Experiments folder management: 
#if not os.path.exists('/Experiments'):
#    os.makedirs('/Experiments') 
if not os.path.exists('Experiments/'+ str(experiment)):
    os.makedirs('Experiments/'+ str(experiment))
else:
    shutil.rmtree('Experiments/'+ str(experiment))          #removes all the subdirectories!
    os.makedirs('Experiments/'+ str(experiment))
#writer = pd.ExcelWriter('Experiments/'+ str(experiment) + '/df.xlsx') 



text_file = open('Experiments/'+ str(experiment) +'/parameters.txt', "w")
text_file.write('experiment: ' + str(experiment)+ '\n')
text_file.write('number of experiments: ' + str(number_of_experiment)+ '\n')
text_file.write('file: ' + str(file)+ '\n')
text_file.write('learner model: ' + str(learner_model)+ '\n')
text_file.write('episode size: ' + str(episode_size)+ '\n')
#text_file.write('numbers of epocs: ' + str(epocs)+ '\n')
text_file.write('internal trashold: ' + str(internal_trashold)+ '\n')
text_file.write('external trashold: ' + str(external_trashold)+ '\n')
 
text_file.close()

# %%
# Classical Learner based on a simple ANN
class ClassicalLearner(nn.Module):
    def __init__(self, num_layers=2, hidden_size=5):
        super().__init__()
        self.layers = None
        self.sigmoid = nn.Sigmoid()

    def initialize_layers(self, input_size, num_layers, hidden_size=5):
        layers = [input_size] + [hidden_size] * (num_layers - 1) + [1]
        self.layers = nn.ModuleList([nn.Linear(layers[i], layers[i+1], dtype=torch.float64) for i in range(len(layers) - 1)])
    
    def forward(self, x):
        x = x.to(torch.float64)
        for layer in self.layers[:-1]:
            x = torch.relu(layer(x))
        return self.sigmoid(self.layers[-1](x))
    
    def fit(self, X_train, y_train, num_it=50, lr=0.01):
        input_size = X_train.shape[1]
        self.initialize_layers(input_size, num_layers=2)
        optimizer = optim.Adam(self.parameters(), lr=lr)
        y_train = torch.tensor(y_train.values, dtype=torch.float64).reshape(-1, 1)
        
        for epoch in range(num_it):
            optimizer.zero_grad()
            y_pred = self.forward(torch.tensor(X_train.values, dtype=torch.float64)).reshape(-1, 1)
            loss = nn.BCELoss()(y_pred, y_train)
            loss.backward()
            optimizer.step()
        
        return self
    
    def predict(self, X_test):
        with torch.no_grad():
            X_test_tensor = torch.tensor(X_test.values, dtype=torch.float64)
            y_pred = self.forward(X_test_tensor).reshape(-1, 1)
            return (y_pred.numpy().flatten() > 0.5).astype(int)

# %%
# Quantum Learner based on Benedetti et al.
class QuantumLearner:
    def __init__(self, num_layers=2):
        self.num_layers = num_layers
        self.weights = None
        self.bias = None
        self.num_qubits = None
        self.dev = None
        self.opt = qml.optimize.AdamOptimizer(0.05)

    def _initialize_circuit(self, num_features):
        # Update the number of qubits to match the current feature count.
        self.num_qubits = num_features
        #self.dev = qml.device('qiskit.aer', wires=list(range(self.num_qubits)))
        self.dev = qml.device("default.qubit", wires=list(range(self.num_qubits)))

        @qml.qnode(self.dev, interface="autograd")
        def circuit(weights, x):
            self.feature_encoding(x)
            for W in weights:
                self.variational_layer(W)
            return qml.expval(qml.PauliZ(0))
        
        self.circuit = circuit

    def feature_encoding(self, x):
        for i in range(self.num_qubits):
            qml.RY(np.pi * x[i], wires=i)
        for i in range(self.num_qubits - 1):
            qml.CZ(wires=[i, i + 1])

    def variational_layer(self, W):
        for i in range(self.num_qubits):
            qml.Rot(W[i, 0], W[i, 1], W[i, 2], wires=i)
        for i in range(self.num_qubits - 1):
            qml.CNOT(wires=[i, i + 1])
        if self.num_qubits > 1:
            qml.CNOT(wires=[self.num_qubits - 1, 0])

    def variational_classifier(self, weights, bias, x):
        return self.circuit(weights, x) + bias

    def cost(self, weights, bias, X, Y):
        # X is expected to be a NumPy array.
        predictions = qml.numpy.array([self.variational_classifier(weights, bias, x) for x in X])
        return qml.numpy.mean((qml.numpy.array(Y) - predictions) ** 2)

    def fit(self, X_train, y_train, num_it=10, batch_size=48, warm_start=False):
        """
        Train the QuantumLearner with debug logging to track performance bottlenecks.
        """
        print("🚀 [QuantumLearner] Starting fit function...")
    
        # Convert inputs to NumPy arrays if needed.
        if hasattr(X_train, "values"):
            X_train = X_train.values.astype(np.float64)
        else:
            X_train = np.array(X_train, dtype=np.float64)
        if hasattr(y_train, "values"):
            y_train = y_train.values
        else:
            y_train = np.array(y_train)
    
        print(f"📊 Dataset size: X_train={X_train.shape}, y_train={y_train.shape}")
    
        current_features = X_train.shape[1]
    
        # If not warm starting or if the number of features has changed, reinitialize the circuit.
        if not warm_start or (self.num_qubits is None) or (self.num_qubits != current_features):
            print("🔄 Reinitializing circuit...")
            self._initialize_circuit(current_features)
            np.random.seed(0)
            self.weights = qml.numpy.tensor(
                0.01 * np.random.randn(self.num_layers, self.num_qubits, 3),
                requires_grad=True,
            )
            self.bias = qml.numpy.tensor(0.0, requires_grad=True)
            print(f"✅ Initialized circuit with {self.num_qubits} qubits")
    
        batch_size = min(batch_size, len(X_train))
        print(f"📌 Using batch size: {batch_size}")
    
        # Track total training time
        start_time = time.time()
    
        for it in range(num_it):
            print(f"⏳ Epoch {it+1}/{num_it}")
    
            batch_start = time.time()
            batch_index = np.random.choice(len(X_train), batch_size, replace=False)
            X_batch = X_train[batch_index]
            Y_batch = y_train[batch_index]
            batch_time = time.time() - batch_start
            #print(f"🛠 Batch selection completed in {batch_time:.2f} seconds")
    
            # Time the optimization step
            opt_start = time.time()
            self.weights, self.bias = self.opt.step(
                lambda w, b: self.cost(w, b, X_batch, Y_batch), self.weights, self.bias
            )
            opt_time = time.time() - opt_start
            #print(f"✅ Optimization step completed in {opt_time:.2f} seconds")
    
        total_time = time.time() - start_time
        print(f"🚀 Training completed in {total_time:.2f} seconds")
    
        return self


    def predict(self, X_test):
        if hasattr(X_test, "values"):
            X_test = X_test.values.astype(np.float64)
        else:
            X_test = np.array(X_test, dtype=np.float64)
        return np.array([
            float(qml.numpy.sign(self.variational_classifier(self.weights, self.bias, x)))
            for x in X_test
        ])

# %%
import pennylane as qml
import numpy as np

class QuantumFeatureSelection:
    def __init__(self, num_features, learning_rate=0.1):
        self.num_features = num_features  # Number of possible features
        self.learning_rate = learning_rate  # Learning rate
        #self.device = qml.device("lightning.gpu", wires=self.num_features)
        self.device = qml.device("default.qubit", wires=self.num_features)
        self.state = self.initialize_state()

    def initialize_state(self):
        """Initialize the quantum state as an equal superposition over all features."""
        @qml.qnode(self.device)
        def circuit():
            for qubit in range(self.num_features):
                qml.Hadamard(wires=qubit)  # Create equal superposition of all features
            return qml.probs(wires=range(self.num_features))  # Get probability distribution
        
        state_vector = np.array(circuit())  # Convert to NumPy array
        state_vector = state_vector[:self.num_features]  # Extract relevant part
        state_vector /= state_vector.sum()  # Normalize to ensure probability sum is 1
        return state_vector

    def measure(self, available_features):
        """Measure the quantum state and return a valid feature (action)."""
        probabilities = self.state  # Already a probability distribution
    
        if not available_features:
            raise ValueError("No available features for selection.")
    
        # Only consider the probabilities of available features
        valid_probs = np.array([probabilities[i] for i in available_features], dtype=np.float64)
    
        print(f"🔎 Available features: {available_features}")
        print(f"🧐 Raw valid_probs before normalization: {valid_probs}")
    
        # Normalize the probabilities
        prob_sum = valid_probs.sum()
        if prob_sum == 0:
            print("⚠️ Warning: All probabilities are zero, using uniform distribution.")
            valid_probs = np.ones(len(available_features), dtype=np.float64) / len(available_features)
        else:
            valid_probs /= prob_sum
    
        print(f"✅ Valid probabilities after normalization: {valid_probs}")
    
        # Ensure arrays have matching lengths
        if len(valid_probs) != len(available_features):
            raise ValueError(f"Size mismatch: available_features={len(available_features)}, valid_probs={len(valid_probs)}")
    
        action = np.random.choice(available_features, p=valid_probs)
        return action

    def unitary_update(self, action, reward):
        """Update the quantum state using a reinforcement learning-inspired unitary operation."""
        if len(self.state.shape) > 1:
            self.state = self.state.flatten()
    
        # Ensure the state is float64
        self.state = self.state.astype(np.float64)
    
        U = np.eye(self.num_features, dtype=np.float64)  # Identity matrix as float64
    
        if reward > 0:
            U[action, action] += self.learning_rate  # Reinforce good actions
        else:
            U[action, action] -= self.learning_rate  # Reduce weight for bad actions
    
        # Apply transformation in probability space
        new_state = U @ self.state  # Matrix-vector multiplication
        new_state = np.abs(new_state)  # Ensure non-negative values
    
        # Avoid division by zero in normalization
        state_sum = np.sum(new_state, dtype=np.float64)
        if state_sum == 0:
            print("Warning: Normalization issue in unitary_update. Resetting state.")
            new_state = np.full(self.num_features, 1 / self.num_features, dtype=np.float64)
        else:
            new_state /= state_sum  # Normalize to maintain probabilities
    
        self.state = new_state.astype(np.float64)  # Ensure final state is float64

# %% [markdown]
# #### 4. Run all experiments

# %%
for e in range (number_of_experiment):
    if not os.path.exists('Experiments/'+ str(experiment)+ '/'+ str(e)):
        os.makedirs('Experiments/'+ str(experiment)+ '/'+ str(e))
    else:
        shutil.rmtree('Experiments/'+ str(experiment)+ '/'+ str(e))          #removes all the subdirectories!
        os.makedirs('Experiments/'+ str(experiment)+ '/'+ str(e))
    print ('Experiments ' + str(e) + ' start')
##########################Experiment setup##########################
    # Read the data
    data = pd.read_csv(location + '/' + filename, index_col=0)
    
##### for run time - start #####
    import timeit
    start = timeit.default_timer()
    size= int(N_data* len(data.index))
    data = data.sample(n=size)
    data=data.iloc[:,-N_features-1:]
##### for run time - end #####
    
    #Set the number of iterations:
    interations=10*len(data.index)/episode_size
    # Set the number of columns exclude the class column
    number_of_columns=data.shape[1]-1 
    print ("number of columns: "+ str(number_of_columns) +" (exclude class column)" ) 
    # Set the number of episodes 
    # episodes_number=epocs*len(data.index)/episode_size
    episodes_number=interations
    print ("Number of episodes: "+ str(episodes_number) ) 
    # Initialize matrix Q as a 1 values matrix:
    #Q = np.matrix(np.ones([number_of_columns+1,number_of_columns+1])) # we will use the last dummy columns as initial state s
    Q = np.matrix(np.ones([number_of_columns+1,number_of_columns+1])) # we will use the last dummy columns as initial state s
    # Set initial_state to be the last dummy column we have created
    initial_state=number_of_columns
    # define data frame to save episode policies results
    df = pd.DataFrame(columns=('episode','episode_columns','policy_columns','policy_accuracy_train','policy_accuracy_test'))
    print ("initial state number: "+ str(initial_state) + " (the last dummy column we have created)") 

    ##########################  episode  ##########################  
    for i in range (int(episodes_number)):
    ########## Begining of episode  ############
        # Initiate lists for available_act, episode_columns and and the policy mode & episode_error
        episode_available_act=list(np.arange(number_of_columns))
        episode_columns=[]
        policy=0
        episode_error=0
        # Initiate the error to 0.5
        episode_last_error=0.5
        # Initiate current_state to be initial_state
        episode_current_state=initial_state
        # Create the episode data 
        episode= get_data(episode_size, policy=0, mode='train')
        # Separate the episode data into features and label
        X_episode,y_episode=data_separate(episode)
        # Split the data into train and test 
        X_train_main_episode, X_test_main_episode, y_train_episode, y_test_episode = data_split(X_episode,y_episode)
        if i<episodes_number*0.25:
            epsilon=0.9
            learning_rate=0.09
        elif i<episodes_number*0.5:
            epsilon=0.5
            learning_rate=0.05
        elif i<episodes_number*0.75:
            epsilon=0.3
            learning_rate=0.01
        else:
            epsilon=0.1
            learning_rate=0.005
        ########## Q learning start ############

        # Initialize Quantum RL feature selection
        quantum_rl = QuantumFeatureSelection(num_features=number_of_columns)
        
        # While there are features left to select
        # while len(episode_available_act) > 0:
        #     # Select next feature using quantum measurement
        #     episode_action = quantum_rl.measure(episode_available_act)
        
        #     # Update the selected feature list
        #     episode_columns = update_columns(episode_action, episode_columns)
        
        #     # Prepare training dataset with selected features
        #     X_train_episode, X_test_episode = update_X_train_X_test(episode_columns, X_train_main_episode, X_test_main_episode)
        
        #     # Evaluate the model accuracy with the selected features
        #     episode_error = Learner(X_train_episode, X_test_episode, y_train_episode, y_test_episode)
        
        #     # Compute reward based on improvement
        #     episode_reward = episode_last_error - episode_error
        
        #     # Quantum RL update step
        #     quantum_rl.unitary_update(episode_action, episode_reward)
        
        #     # Move to next state (selected feature)
        #     episode_current_state = episode_action
        #     episode_last_error = episode_error


        while len(episode_available_act) > 0:
            print(f"\n🟢 Available features: {episode_available_act}")
        
            # Determine exploration vs. exploitation
            exploration = exploration_explotation(epsilon)  # 🔥 Fix: Define exploration
        
            # Update the available actions list
            episode_available_act = available_actions(number_of_columns, episode_columns, initial_state, episode_current_state, internal_trashold, exploration)
            
            # If no available actions remain, terminate the loop
            if len(episode_available_act) == 0:
                print("❌ No available actions left. Terminating episode.")
                break
        
            # Select next feature using quantum measurement
            episode_action = quantum_rl.measure(episode_available_act)
            print(f"🎯 Selected feature: {episode_action}")
        
            # Update the selected feature list
            episode_columns = update_columns(episode_action, episode_columns)
            print(f"📌 Updated selected features: {episode_columns}")
        
            # Prepare training dataset with selected features
            X_train_episode, X_test_episode = update_X_train_X_test(
                episode_columns, X_train_main_episode, X_test_main_episode
            )
            print(f"📊 Training set shape: {X_train_episode.shape}, Test set shape: {X_test_episode.shape}")

            # Evaluate the model accuracy with the selected features
            episode_error = Learner(X_train_episode, X_test_episode, y_train_episode, y_test_episode)
            print(f"📉 Model error after selection: {episode_error}")
        
            # Compute reward based on improvement
            episode_reward = episode_last_error - episode_error
            print(f"🏆 Computed Reward: {episode_reward}")
        
            # Quantum RL update step
            quantum_rl.unitary_update(episode_action, episode_reward)
            print(f"🔄 Updated Quantum State: {quantum_rl.state}")
        
            # Move to next state (selected feature)
            episode_current_state = episode_action
            episode_last_error = episode_error

        print("Q learning End.")
        ########## Q learning End ############

        #Save Q matrix: 
        if (i%100 ==0):
            Q_save=pd.DataFrame(Q)
            Q_save.to_csv('Experiments/'+ str(experiment)+ '/'+ str(e)+ '/Q.'+ str(i+1) + '.csv') 
            
        print("Calculating policy...")
        # Calculate policy 
        policy_available_actions=list(np.arange(number_of_columns))
        policy_columns=[]
        policy_current_state=initial_state
        while len(policy_available_actions)>0:
            # Get available actions in the current state
            policy_available_actions = available_actions(number_of_columns,policy_columns,initial_state,policy_current_state, external_trashold, exploration=0)
            # # Sample next action to be performed
            if len(policy_available_actions)>0:
                policy_select_action = sample_next_action(policy_current_state, Q, policy_available_actions, exploration=0)
                # Update the episode_columns
                policy_columns=update_columns(policy_select_action,policy_columns)
                policy_current_state=policy_select_action

        print("Calculating policy_accuracy...")
        # Calculate policy_accuracy    
        if len(policy_columns)>0:
            ##for training dataset##
            policy_data=get_data(episode_size,policy=1,mode='train')
            X_policy,y_policy=data_separate(policy_data)
            X_train_main_policy, X_test_main_policy, y_train_policy, y_test_policy = data_split(X,y)
            X_train_policy, X_test_policy =update_X_train_X_test(policy_columns, X_train_main_policy, X_test_main_policy)
            

            # Print dataset shape before training to check if it's too large
            print(f"📊 Policy dataset shape: Train={X_train_policy.shape}, Test={X_test_policy.shape}")
            
            # Time the execution of the Learner function
            print("⏳ Running Learner...", X_train_policy, X_test_policy, y_train_policy, y_test_policy)
            start_time = time.time()
            policy_error = Learner(X_train_policy, X_test_policy, y_train_policy, y_test_policy)
            end_time = time.time()
            
            # Print execution time
            print(f"✅ Learner execution time: {end_time - start_time:.2f} seconds")

            
            
            
            policy_accuracy_train=1-policy_error
            ##for testing dataset##
            policy_data=get_data(episode_size,policy=1,mode='test')
            X_policy,y_policy=data_separate(policy_data)
            X_train_main_policy, X_test_main_policy, y_train_policy, y_test_policy = data_split(X,y)
            X_train_policy, X_test_policy =update_X_train_X_test(policy_columns, X_train_main_policy, X_test_main_policy)
            policy_error=Learner(X_train_policy, X_test_policy,y_train_policy, y_test_policy)
            policy_accuracy_test=1-policy_error 
        else:
            policy_accuracy_train=0 
            policy_accuracy_test=0
        #df=df.append({'episode':str(i+1), 'episode_columns':str(episode_columns),'policy_columns':str(policy_columns),'policy_accuracy_train':policy_accuracy_train,'policy_accuracy_test':policy_accuracy_test}, ignore_index=True)
        #new_row = pd.DataFrame([{'episode': str(i+1),
        #                  'episode_columns': str(episode_columns),
        #                  'policy_columns': str(policy_columns),
        #                  'policy_accuracy_train': policy_accuracy_train,
        #                  'policy_accuracy_test': policy_accuracy_test}])
        #df = pd.concat([df, new_row], ignore_index=True)
        df.loc[len(df)] = {
            'episode': str(i+1),
            'episode_columns': str(episode_columns),
            'policy_columns': str(policy_columns),
            'policy_accuracy_train': policy_accuracy_train,
            'policy_accuracy_test': policy_accuracy_test
        }

        #Prints
        print ("episode "+ str(i+1) +" start") 
        print ("episode columns: "+ str(episode_columns) + " epsilon: " + str(epsilon) + " learning rate: " + str(learning_rate) + " error: " +str(episode_error))
        print ("episode policy:" + str(policy_columns) + " train accuracy: " + str(policy_accuracy_train)  + " test accuracy: " +str(policy_accuracy_test)) 
        print ("episode "+ str(i+1) +" end") 
    ########## End of episode  ############
    #df.to_excel(writer, 'Experiment' + str(e))
    df.to_excel(writer, sheet_name='Experiment' + str(e))
    df_plot=df[['episode','policy_accuracy_train','policy_accuracy_test']]
    plot=df_plot.plot()
    fig = plot.get_figure()
    fig.savefig('Experiments/'+ str(experiment) + '/plot_experiment_' + str(e) +'.png')
    
#writer.save()
with pd.ExcelWriter('Experiments/'+ str(experiment) + '/df.xlsx') as writer:
    df.to_excel(writer, sheet_name='Experiment' + str(e))

## for run time ##
stop = timeit.default_timer()
print (stop - start)
## for run time ##
# Out:
# Experiments 0 start
# number of columns: 2 (exclude class column)
# Number of episodes: 2443.0
# initial state number: 2 (the last dummy column we have created)
#
# 🟢 Available features: [np.int64(0), np.int64(1)]
# 🔎 Available features: [np.int64(0), np.int64(1)]
# 🧐 Raw valid_probs before normalization: [0.5 0.5]
# ✅ Valid probabilities after normalization: [0.5 0.5]
# 🎯 Selected feature: 0
# 📌 Updated selected features: [np.int64(0)]
# 📊 Training set shape: (80, 1), Test set shape: (20, 1)
# 🚀 [QuantumLearner] Starting fit function...
# 📊 Dataset size: X_train=(80, 1), y_train=(80,)
# 🔄 Reinitializing circuit...
# ✅ Initialized circuit with 1 qubits
# 📌 Using batch size: 48
# ⏳ Epoch 1/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.10 seconds
# ⏳ Epoch 2/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.26 seconds
# ⏳ Epoch 3/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 4/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 5/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 6/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 7/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 8/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 9/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 10/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 11/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 12/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 13/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 14/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 15/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 16/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.22 seconds
# ⏳ Epoch 17/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 18/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 19/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 20/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 21/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 22/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 23/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 24/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 25/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 26/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 27/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 28/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 29/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 30/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 31/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 32/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 33/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 34/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 35/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 36/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 37/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 38/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 39/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 40/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 41/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 42/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 43/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 44/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 45/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 46/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 47/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 48/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.24 seconds
# ⏳ Epoch 49/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 50/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 51/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 52/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 53/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.24 seconds
# ⏳ Epoch 54/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 55/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 56/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 57/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 58/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 59/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.08 seconds
# ⏳ Epoch 60/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 61/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 62/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 63/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 64/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 65/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 66/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 67/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 68/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 69/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 70/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 71/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 72/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 73/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 74/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 75/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 76/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 77/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 78/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 79/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 80/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 81/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 82/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 83/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 84/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 85/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 86/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 87/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 88/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 89/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 90/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 91/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 92/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 93/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 94/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 95/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 96/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 97/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 98/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 99/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 100/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.24 seconds
# 🚀 Training completed in 12.13 seconds
# 📉 Model error after selection: 0.7
# 🏆 Computed Reward: -0.19999999999999996
# 🔄 Updated Quantum State: [0.47368421 0.52631579]
#
# 🟢 Available features: [np.int64(0), np.int64(1)]
# 🔎 Available features: [np.int64(1)]
# 🧐 Raw valid_probs before normalization: [0.52631579]
# ✅ Valid probabilities after normalization: [1.]
# 🎯 Selected feature: 1
# 📌 Updated selected features: [np.int64(0), np.int64(1)]
# 📊 Training set shape: (80, 2), Test set shape: (20, 2)
# 🚀 [QuantumLearner] Starting fit function...
# 📊 Dataset size: X_train=(80, 2), y_train=(80,)
# 🔄 Reinitializing circuit...
# ✅ Initialized circuit with 2 qubits
# 📌 Using batch size: 48
# ⏳ Epoch 1/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 2/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 3/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 4/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 5/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 6/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 7/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 8/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 9/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 10/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 11/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 12/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 13/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 14/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 15/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 16/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 17/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 18/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 19/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.36 seconds
# ⏳ Epoch 20/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 21/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 22/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 23/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 24/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 25/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 26/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 27/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 28/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 29/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 30/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 31/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 32/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 33/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 34/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 35/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 36/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 37/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 38/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 39/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 40/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 41/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.17 seconds
# ⏳ Epoch 42/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 43/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 44/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.17 seconds
# ⏳ Epoch 45/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 46/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 47/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 48/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 49/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 50/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 51/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 52/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 53/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 54/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 55/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 56/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 57/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 58/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 59/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 60/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 61/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.35 seconds
# ⏳ Epoch 62/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 63/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 64/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 65/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 66/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 67/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.17 seconds
# ⏳ Epoch 68/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 69/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 70/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 71/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.20 seconds
# ⏳ Epoch 72/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.35 seconds
# ⏳ Epoch 73/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 74/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 75/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 76/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 77/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 78/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 79/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 80/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 81/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 82/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 83/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 84/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 85/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 86/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 87/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 88/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 89/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 90/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 91/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 92/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 93/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 94/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 95/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 96/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 97/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 98/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 99/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 100/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# 🚀 Training completed in 25.25 seconds
# 📉 Model error after selection: 0.7
# 🏆 Computed Reward: 0.0
# 🔄 Updated Quantum State: [0.5 0.5]
#
# 🟢 Available features: [np.int64(1)]
# ❌ No available actions left. Terminating episode.
# Q learning End.
# Calculating policy...
# Calculating policy_accuracy...
# 📊 Policy dataset shape: Train=(19544, 2), Test=(4886, 2)
# ⏳ Running Learner...
# 🚀 [QuantumLearner] Starting fit function...
# 📊 Dataset size: X_train=(19544, 2), y_train=(19544,)
# 🔄 Reinitializing circuit...
# ✅ Initialized circuit with 2 qubits
# 📌 Using batch size: 48
# ⏳ Epoch 1/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 2/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 3/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 4/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 5/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 6/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 7/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 8/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 9/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 10/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 11/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 12/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 13/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 14/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 15/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 16/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 17/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 18/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 19/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 20/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 21/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 22/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 23/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 24/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 25/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 26/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 27/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.17 seconds
# ⏳ Epoch 28/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 29/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 30/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 31/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 32/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 33/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 34/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 35/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 36/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 37/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 38/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 39/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 40/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 41/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 42/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 43/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 44/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 45/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 46/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 47/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 48/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 49/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 50/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 51/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 52/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 53/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 54/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 55/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 56/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 57/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 58/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 59/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 60/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 61/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 62/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 63/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 64/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 65/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 66/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 67/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 68/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 69/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 70/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 71/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 72/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 73/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 74/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 75/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 76/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 77/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 78/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 79/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 80/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 81/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 82/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 83/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 84/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 85/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 86/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 87/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 88/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 89/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.17 seconds
# ⏳ Epoch 90/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 91/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 92/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 93/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 94/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 95/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 96/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 97/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 98/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 99/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 100/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# 🚀 Training completed in 25.51 seconds
# ✅ Learner execution time: 32.42 seconds
# 🚀 [QuantumLearner] Starting fit function...
# 📊 Dataset size: X_train=(2172, 2), y_train=(2172,)
# 🔄 Reinitializing circuit...
# ✅ Initialized circuit with 2 qubits
# 📌 Using batch size: 48
# ⏳ Epoch 1/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 2/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 3/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 4/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 5/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 6/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 7/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 8/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 9/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 10/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 11/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 12/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 13/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 14/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 15/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 16/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 17/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 18/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 19/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 20/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 21/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 22/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 23/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 24/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 25/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 26/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 27/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 28/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 29/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 30/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 31/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 32/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 33/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 34/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 35/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 36/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 37/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 38/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 39/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 40/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 41/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 42/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 43/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 44/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 45/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 46/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 47/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 48/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 49/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 50/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 51/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 52/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 53/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 54/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 55/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 56/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 57/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 58/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 59/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 60/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 61/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 62/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 63/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 64/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 65/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 66/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 67/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 68/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 69/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 70/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 71/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 72/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 73/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 74/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 75/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 76/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.32 seconds
# ⏳ Epoch 77/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 78/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 79/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 80/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 81/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 82/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 83/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 84/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 85/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 86/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.34 seconds
# ⏳ Epoch 87/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 88/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 89/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 90/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 91/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 92/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 93/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 94/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.19 seconds
# ⏳ Epoch 95/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 96/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 97/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 98/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# ⏳ Epoch 99/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.33 seconds
# ⏳ Epoch 100/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.18 seconds
# 🚀 Training completed in 25.30 seconds
# episode 1 start
# episode columns: [np.int64(0), np.int64(1)] epsilon: 0.9 learning rate: 0.09 error: 0.7
# episode policy:[np.int64(1), np.int64(0)] train accuracy: 0.2544003274662301 test accuracy: 0.24677716390423576
# episode 1 end
#
# 🟢 Available features: [np.int64(0), np.int64(1)]
# 🔎 Available features: [np.int64(0), np.int64(1)]
# 🧐 Raw valid_probs before normalization: [0.5 0.5]
# ✅ Valid probabilities after normalization: [0.5 0.5]
# 🎯 Selected feature: 1
# 📌 Updated selected features: [np.int64(1)]
# 📊 Training set shape: (80, 1), Test set shape: (20, 1)
# 🚀 [QuantumLearner] Starting fit function...
# 📊 Dataset size: X_train=(80, 1), y_train=(80,)
# 🔄 Reinitializing circuit...
# ✅ Initialized circuit with 1 qubits
# 📌 Using batch size: 48
# ⏳ Epoch 1/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 2/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 3/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 4/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 5/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 6/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 7/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 8/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 9/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 10/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 11/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 12/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 13/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 14/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 15/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 16/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 17/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 18/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 19/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 20/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.24 seconds
# ⏳ Epoch 21/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 22/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 23/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 24/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 25/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.23 seconds
# ⏳ Epoch 26/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 27/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 28/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 29/100
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.09 seconds
# ⏳ Epoch 30/100
# 🛠 Batch selection completed in 0.00 seconds
# ...
#     248         )
#
# File ~/.venv/lib/python3.13/site-packages/autograd/core.py:10, in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root()
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# File ~/.venv/lib/python3.13/site-packages/autograd/tracer.py:10, in trace(start_node, fun, x)
#       8 with trace_stack.new_trace() as t:
#       9     start_box = new_box(x, t, start_node)
# ---> 10     end_box = fun(start_box)
#      11     if isbox(end_box) and end_box._trace == start_box._trace:
#      12         return end_box._value, end_box._node
#
# File ~/.venv/lib/python3.13/site-packages/autograd/wrap_util.py:15, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f.<locals>.unary_f(x)
#      13 else:
#      14     subargs = subvals(args, zip(argnum, x))
# ---> 15 return fun(*subargs, **kwargs)
#
# Cell In[116], line 99, in QuantumLearner.fit.<locals>.<lambda>(w, b)
#      96 # Time the optimization step
#      97 opt_start = time.time()
#      98 self.weights, self.bias = self.opt.step(
# ---> 99     lambda w, b: self.cost(w, b, X_batch, Y_batch), self.weights, self.bias
#     100 )
#     101 opt_time = time.time() - opt_start
#     102 print(f"✅ Optimization step completed in {opt_time:.2f} seconds")
#
# Cell In[116], line 45, in QuantumLearner.cost(self, weights, bias, X, Y)
#      43 def cost(self, weights, bias, X, Y):
#      44     # X is expected to be a NumPy array.
# ---> 45     predictions = qml.numpy.array([self.variational_classifier(weights, bias, x) for x in X])
#      46     return qml.numpy.mean((qml.numpy.array(Y) - predictions) ** 2)
#
# Cell In[116], line 41, in QuantumLearner.variational_classifier(self, weights, bias, x)
#      40 def variational_classifier(self, weights, bias, x):
# ---> 41     return self.circuit(weights, x) + bias
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/workflow/qnode.py:905, in QNode.__call__(self, *args, **kwargs)
#     903 if qml.capture.enabled():
#     904     return capture_qnode(self, *args, **kwargs)
# --> 905 return self._impl_call(*args, **kwargs)
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/workflow/qnode.py:881, in QNode._impl_call(self, *args, **kwargs)
#     878 # Calculate the classical jacobians if necessary
#     879 self._transform_program.set_classical_component(self, args, kwargs)
# --> 881 res = qml.execute(
#     882     (tape,),
#     883     device=self.device,
#     884     diff_method=self.diff_method,
#     885     interface=interface,
#     886     transform_program=self._transform_program,
#     887     gradient_kwargs=self.gradient_kwargs,
#     888     **self.execute_kwargs,
#     889 )
#     890 res = res[0]
#     892 # convert result to the interface in case the qfunc has no parameters
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/workflow/execution.py:232, in execute(tapes, device, diff_method, interface, transform_program, inner_transform, config, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, device_vjp, mcm_config, gradient_fn)
#     229 if transform_program.is_informative:
#     230     return post_processing(tapes)
# --> 232 results = run(tapes, device, config, inner_transform)
#     233 return post_processing(results)
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/workflow/run.py:287, in run(tapes, device, config, inner_transform_program)
#     278 no_interface_boundary_required = (
#     279     config.interface == Interface.NUMPY
#     280     or config.gradient_method
#    (...)
#     284     }
#     285 )
#     286 if no_interface_boundary_required:
# --> 287     results = inner_execute(tapes)
#     288     return results
#     290 # TODO: Prune once support for tf-autograph is dropped
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/workflow/run.py:247, in _make_inner_execute.<locals>.inner_execute(tapes)
#     244 transformed_tapes, transform_post_processing = inner_transform(tapes)
#     246 if transformed_tapes:
# --> 247     results = device.execute(transformed_tapes, execution_config=execution_config)
#     248 else:
#     249     results = ()
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/devices/modifiers/simulator_tracking.py:30, in _track_execute.<locals>.execute(self, circuits, execution_config)
#      28 @wraps(untracked_execute)
#      29 def execute(self, circuits, execution_config=DefaultExecutionConfig):
# ---> 30     results = untracked_execute(self, circuits, execution_config)
#      31     if isinstance(circuits, QuantumScript):
#      32         batch = (circuits,)
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/devices/modifiers/single_tape_support.py:32, in _make_execute.<locals>.execute(self, circuits, execution_config)
#      30     is_single_circuit = True
#      31     circuits = (circuits,)
# ---> 32 results = batch_execute(self, circuits, execution_config)
#      33 return results[0] if is_single_circuit else results
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/logging/decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/devices/default_qubit.py:630, in DefaultQubit.execute(self, circuits, execution_config)
#     627 prng_keys = [self.get_prng_keys()[0] for _ in range(len(circuits))]
#     629 if max_workers is None:
# --> 630     return tuple(
#     631         _simulate_wrapper(
#     632             c,
#     633             {
#     634                 "rng": self._rng,
#     635                 "debugger": self._debugger,
#     636                 "interface": interface,
#     637                 "state_cache": self._state_cache,
#     638                 "prng_key": _key,
#     639                 "mcm_method": execution_config.mcm_config.mcm_method,
#     640                 "postselect_mode": execution_config.mcm_config.postselect_mode,
#     641             },
#     642         )
#     643         for c, _key in zip(circuits, prng_keys)
#     644     )
#     646 vanilla_circuits = convert_to_numpy_parameters(circuits)[0]
#     647 seeds = self._rng.integers(2**31 - 1, size=len(vanilla_circuits))
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/devices/default_qubit.py:631, in <genexpr>(.0)
#     627 prng_keys = [self.get_prng_keys()[0] for _ in range(len(circuits))]
#     629 if max_workers is None:
#     630     return tuple(
# --> 631         _simulate_wrapper(
#     632             c,
#     633             {
#     634                 "rng": self._rng,
#     635                 "debugger": self._debugger,
#     636                 "interface": interface,
#     637                 "state_cache": self._state_cache,
#     638                 "prng_key": _key,
#     639                 "mcm_method": execution_config.mcm_config.mcm_method,
#     640                 "postselect_mode": execution_config.mcm_config.postselect_mode,
#     641             },
#     642         )
#     643         for c, _key in zip(circuits, prng_keys)
#     644     )
#     646 vanilla_circuits = convert_to_numpy_parameters(circuits)[0]
#     647 seeds = self._rng.integers(2**31 - 1, size=len(vanilla_circuits))
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/devices/default_qubit.py:918, in _simulate_wrapper(circuit, kwargs)
#     917 def _simulate_wrapper(circuit, kwargs):
# --> 918     return simulate(circuit, **kwargs)
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/logging/decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/devices/qubit/simulate.py:357, in simulate(circuit, debugger, state_cache, **execution_kwargs)
#     354     return tuple(results)
#     356 ops_key, meas_key = jax_random_split(prng_key)
# --> 357 state, is_state_batched = get_final_state(
#     358     circuit, debugger=debugger, prng_key=ops_key, **execution_kwargs
#     359 )
#     360 if state_cache is not None:
#     361     state_cache[circuit.hash] = state
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/logging/decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/devices/qubit/simulate.py:190, in get_final_state(circuit, debugger, **execution_kwargs)
#     188 if isinstance(op, MidMeasureMP):
#     189     prng_key, key = jax_random_split(prng_key)
# --> 190 state = apply_operation(
#     191     op,
#     192     state,
#     193     is_state_batched=is_state_batched,
#     194     debugger=debugger,
#     195     prng_key=key,
#     196     tape_shots=circuit.shots,
#     197     **execution_kwargs,
#     198 )
#     199 # Handle postselection on mid-circuit measurements
#     200 if isinstance(op, qml.Projector):
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/functools.py:931, in singledispatch.<locals>.wrapper(*args, **kw)
#     928 if not args:
#     929     raise TypeError(f'{funcname} requires at least '
#     930                     '1 positional argument')
# --> 931 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/devices/qubit/apply_operation.py:231, in apply_operation(op, state, is_state_batched, debugger, **_)
#     165 @singledispatch
#     166 def apply_operation(
#     167     op: qml.operation.Operator,
#    (...)
#     171     **_,
#     172 ):
#     173     """Apply and operator to a given state.
#     174
#     175     Args:
#    (...)
#     229
#     230     """
# --> 231     return _apply_operation_default(op, state, is_state_batched, debugger)
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/devices/qubit/apply_operation.py:241, in _apply_operation_default(op, state, is_state_batched, debugger)
#     235 """The default behaviour of apply_operation, accessed through the standard dispatch
#     236 of apply_operation, as well as conditionally in other dispatches."""
#     237 if (
#     238     len(op.wires) < EINSUM_OP_WIRECOUNT_PERF_THRESHOLD
#     239     and math.ndim(state) < EINSUM_STATE_WIRECOUNT_PERF_THRESHOLD
#     240 ) or (op.batch_size and is_state_batched):
# --> 241     return apply_operation_einsum(op, state, is_state_batched=is_state_batched)
#     242 return apply_operation_tensordot(op, state, is_state_batched=is_state_batched)
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/devices/qubit/apply_operation.py:80, in apply_operation_einsum(op, state, is_state_batched)
#      78     mat = qml.math.cast_like(op.matrix(), state)
#      79 else:
# ---> 80     mat = op.matrix() + 0j
#      82 total_indices = len(state.shape) - is_state_batched
#      83 num_indices = len(op.wires)
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/operation.py:810, in Operator.matrix(self, wire_order)
#     790 def matrix(self, wire_order: Optional[WiresLike] = None) -> TensorLike:
#     791     r"""Representation of the operator as a matrix in the computational basis.
#     792
#     793     If ``wire_order`` is provided, the numerical representation considers the position of the
#    (...)
#     808         tensor_like: matrix representation
#     809     """
# --> 810     canonical_matrix = self.compute_matrix(*self.parameters, **self.hyperparameters)
#     812     if (
#     813         wire_order is None
#     814         or self.wires == Wires(wire_order)
#    (...)
#     818         )
#     819     ):
#     820         return canonical_matrix
#
# File ~/.venv/lib/python3.13/site-packages/pennylane/ops/qubit/parametric_ops_single_qubit.py:649, in Rot.compute_matrix(phi, theta, omega)
#     640 c = c * one
#     641 s = s * one
#     643 mat = [
#     644     [
#     645         qml.math.exp(-0.5j * (phi + omega)) * c,
#     646         -qml.math.exp(0.5j * (phi - omega)) * s,
#     647     ],
#     648     [
# --> 649         qml.math.exp(-0.5j * (phi - omega)) * s,
#     650         qml.math.exp(0.5j * (phi + omega)) * c,
#     651     ],
#     652 ]
#     654 return qml.math.stack([stack_last(row) for row in mat], axis=-2)
#
# File ~/.venv/lib/python3.13/site-packages/autograd/numpy/numpy_boxes.py:28, in ArrayBox.__mul__(self, other)
# ---> 28 def __mul__(self, other): return anp.multiply(self, other)
#
# File ~/.venv/lib/python3.13/site-packages/autograd/tracer.py:45, in primitive.<locals>.f_wrapped(*args, **kwargs)
#      43     argnums = tuple(argnum    for argnum, _   in boxed_args)
#      44     ans = f_wrapped(*argvals, **kwargs)
# ---> 45     node = node_constructor(ans, f_wrapped, argvals, kwargs, argnums, parents)
#      46     return new_box(ans, trace, node)
#      47 else:
#
# File ~/.venv/lib/python3.13/site-packages/autograd/core.py:36, in VJPNode.__init__(self, value, fun, args, kwargs, parent_argnums, parents)
#      33     fun_name = getattr(fun, '__name__', fun)
#      34     raise NotImplementedError("VJP of {} wrt argnums {} not defined"
#      35                               .format(fun_name, parent_argnums))
# ---> 36 self.vjp = vjpmaker(parent_argnums, value, args, kwargs)
#
# File ~/.venv/lib/python3.13/site-packages/autograd/core.py:76, in defvjp.<locals>.vjp_argnums(argnums, ans, args, kwargs)
#      73 except KeyError:
#      74     raise NotImplementedError(
#      75         "VJP of {} wrt argnums 0, 1 not defined".format(fun.__name__))
# ---> 76 vjp_0 = vjp_0_fun(ans, *args, **kwargs)
#      77 vjp_1 = vjp_1_fun(ans, *args, **kwargs)
#      78 return lambda g: (vjp_0(g), vjp_1(g))
#
# File ~/.venv/lib/python3.13/site-packages/autograd/numpy/numpy_vjps.py:33, in <lambda>(ans, x, y)
#      29 # ----- Binary ufuncs -----
#      31 defvjp(anp.add,         lambda ans, x, y : unbroadcast_f(x, lambda g: g),
#      32                         lambda ans, x, y : unbroadcast_f(y, lambda g: g))
# ---> 33 defvjp(anp.multiply,    lambda ans, x, y : unbroadcast_f(x, lambda g: y * g),
#      34                         lambda ans, x, y : unbroadcast_f(y, lambda g: x * g))
#      35 defvjp(anp.subtract,    lambda ans, x, y : unbroadcast_f(x, lambda g: g),
#      36                         lambda ans, x, y : unbroadcast_f(y, lambda g: -g))
#      37 defvjp(anp.divide,      lambda ans, x, y : unbroadcast_f(x, lambda g:   g / y),
#      38                         lambda ans, x, y : unbroadcast_f(y, lambda g: - g * x / y**2))
#
# File ~/.venv/lib/python3.13/site-packages/autograd/numpy/numpy_vjps.py:659, in unbroadcast_f(target, f)
#     658 def unbroadcast_f(target, f):
# --> 659     target_meta = anp.metadata(target)
#     660     return lambda g: unbroadcast(f(g), target_meta)
#
# File ~/.venv/lib/python3.13/site-packages/autograd/tracer.py:61, in notrace_primitive.<locals>.f_wrapped(*args, **kwargs)
#      58 @wraps(f_raw)
#      59 def f_wrapped(*args, **kwargs):
#      60     argvals = map(getval, args)
# ---> 61     return f_raw(*argvals, **kwargs)
#
# File ~/.venv/lib/python3.13/site-packages/autograd/numpy/numpy_wrapper.py:148, in metadata(A)
#     146 @notrace_primitive
#     147 def metadata(A):
# --> 148     return _np.shape(A), _np.ndim(A), _np.result_type(A), _np.iscomplexobj(A)
#
# File ~/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2058, in shape(a)
#    2054 def _shape_dispatcher(a):
#    2055     return (a,)
# -> 2058 @array_function_dispatch(_shape_dispatcher)
#    2059 def shape(a):
#    2060     """
#    2061     Return the shape of an array.
#    2062
#    (...)
#    2097
#    2098     """
#    2099     try:
#
# KeyboardInterrupt:

# %%
import numpy as np

def test_quantum_feature_selection():
    num_features = 4
    learning_rate = 0.1
    qfs = QuantumFeatureSelection(num_features, learning_rate)

    # Test initialization
    assert qfs.state.shape == (num_features,), "State shape is incorrect."
    assert np.isclose(qfs.state.sum(), 1.0), "State is not normalized."

    # Test measurement
    available_features = [0, 1, 2, 3]
    for _ in range(10):
        action = qfs.measure(available_features)
        assert action in available_features, f"Invalid action selected: {action}"

    # Test unitary update
    initial_state = qfs.state.copy()
    qfs.unitary_update(action, reward=1)
    assert np.isclose(qfs.state.sum(), 1.0), "State is not normalized after update."
    assert not np.allclose(qfs.state, initial_state), "State did not change after update."

    # Edge case: No available features
    try:
        qfs.measure([])
        assert False, "Expected ValueError when measuring with no available features."
    except ValueError:
        pass  # Expected behavior

    # Edge case: Unitary update does not lead to zero state
    qfs.unitary_update(action, reward=-1)
    assert np.isclose(qfs.state.sum(), 1.0), "State is not normalized after negative reward update."

    print("All tests passed!")

# Run the test
test_quantum_feature_selection()
# Out:
# All tests passed!

# %%
def test_quantum_learner():
    """Test the QuantumLearner class with basic training and prediction."""
    np.random.seed(42)

    # Sample training data (binary classification, {-1, 1} labels)
    X_train = np.array([
        [0.1, 0.2], 
        [0.2, 0.3], 
        [0.3, 0.4], 
        [0.4, 0.5]
    ])
    y_train = np.array([1, -1, 1, -1])  # Binary labels

    # Initialize QuantumLearner
    ql = QuantumLearner(num_layers=2)

    # Ensure the circuit initializes correctly
    ql._initialize_circuit(num_features=2)
    assert ql.num_qubits == 2, "Circuit initialization failed: Incorrect number of qubits."

    # Test fitting the model
    ql.fit(X_train, y_train, num_it=5)  # Small number of iterations for quick test

    # Ensure the weights and bias are updated
    assert ql.weights is not None, "Weights were not initialized."
    assert ql.bias is not None, "Bias was not initialized."

    # Test prediction on new samples
    X_test = np.array([
        [0.15, 0.25],
        [0.35, 0.45]
    ])
    predictions = ql.predict(X_test)
    
    # Ensure output shape matches input shape
    assert predictions.shape == (X_test.shape[0],), "Prediction output shape mismatch."

    print("✅ All tests passed successfully!")

# Run the test
test_quantum_learner()
# Out:
# 🚀 [QuantumLearner] Starting fit function...
# 📊 Dataset size: X_train=(4, 2), y_train=(4,)
# 🔄 Reinitializing circuit...
# ✅ Initialized circuit with 2 qubits
# 📌 Using batch size: 4
# ⏳ Epoch 1/5
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.04 seconds
# ⏳ Epoch 2/5
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.02 seconds
# ⏳ Epoch 3/5
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.02 seconds
# ⏳ Epoch 4/5
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.02 seconds
# ⏳ Epoch 5/5
# 🛠 Batch selection completed in 0.00 seconds
# ✅ Optimization step completed in 0.02 seconds
# 🚀 Training completed in 0.12 seconds
# ✅ All tests passed successfully!
